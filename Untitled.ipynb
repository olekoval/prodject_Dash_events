# %%
import polars as pl

# %%
df_all = pl.read_parquet("./data/gr_services_all_25_26.parquet")
df_all.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# shape: (2, 4)
# ┌──────┬───────────────────┬──────────────────┬───────────────┐
# │ year ┆ first_letter_code ┆ count_un_patient ┆ count_posluha │
# │ ---  ┆ ---               ┆ ---              ┆ ---           │
# │ str  ┆ str               ┆ i64              ┆ i64           │
# ╞══════╪═══════════════════╪══════════════════╪═══════════════╡
# │ 2026 ┆ ALL               ┆ 8744779          ┆ 52188341      │
# │ 2025 ┆ ALL               ┆ 12957618         ┆ 96864989      │
# └──────┴───────────────────┴──────────────────┴───────────────┘

# %%
df_serv = pl.read_parquet("./data/gr_services_first_letter_25_26.parquet")
df_serv.head(10)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# shape: (10, 4)
# ┌──────┬───────────────────┬──────────────────┬───────────────┐
# │ year ┆ first_letter_code ┆ count_un_patient ┆ count_posluha │
# │ ---  ┆ ---               ┆ ---              ┆ ---           │
# │ str  ┆ str               ┆ i64              ┆ i64           │
# ╞══════╪═══════════════════╪══════════════════╪═══════════════╡
# │ 2026 ┆ C                 ┆ 7135868          ┆ 20813623      │
# │ 2026 ┆ E                 ┆ 253853           ┆ 275923        │
# │ 2026 ┆ I                 ┆ 4694350          ┆ 9248565       │
# │ 2026 ┆ L                 ┆ 3077963          ┆ 17156609      │
# │ 2026 ┆ P                 ┆ 2126436          ┆ 4693621       │
# │ 2025 ┆ C                 ┆ 10731180         ┆ 40717213      │
# │ 2025 ┆ E                 ┆ 330107           ┆ 366343        │
# │ 2025 ┆ I                 ┆ 7810662          ┆ 17025634      │
# │ 2025 ┆ L                 ┆ 5180918          ┆ 29281303      │
# │ 2025 ┆ P                 ┆ 3537838          ┆ 9474496       │
# └──────┴───────────────────┴──────────────────┴───────────────┘
